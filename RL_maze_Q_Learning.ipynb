# %% [markdown]
# <a href="https://colab.research.google.com/github/J-N-ch/RL_MAZE_Q-Learning/blob/master/RL_maze_Q_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Modification from "https://github.com/YutaroOgawa/Deep-Reinforcement-Learning-Book/blob/master/program/2_6_Qlearning.ipynb"
'''

 Using Q-Learning method !!!

'''

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Initialize State of Maze

# Set the size of the Graph
fig = plt.figure( figsize=(10, 10) )
ax  = plt.gca()

# Draw the Red Wall
# [x1, y1] ---> [x2, y2]
#plt.plot([x1, x2], [y1, y2], color='red', linewidth=2)
lwd=12
plt.plot([  0, 0 ], [  0, 10 ], color='red', linewidth=lwd)
plt.plot([  0,10 ], [ 10, 10 ], color='red', linewidth=lwd)
plt.plot([ 10,10 ], [ 10,  0 ], color='red', linewidth=lwd)
plt.plot([ 10, 0 ], [  0,  0 ], color='red', linewidth=lwd)

plt.plot([1, 1    ], [ 1,     1 + 7], color='red', linewidth=lwd)
plt.plot([1, 2    ], [ 2 + 7, 2 + 7], color='red', linewidth=lwd)
plt.plot([2, 2    ], [ 2 + 7, 1 + 7], color='red', linewidth=lwd)
plt.plot([2, 3 + 7], [ 1 + 7, 1 + 7], color='red', linewidth=lwd)
plt.plot([1, 3    ], [-1 + 7,-1 + 7], color='red', linewidth=lwd)
plt.plot([4, 9    ], [-1 + 7,-1 + 7], color='red', linewidth=lwd)
plt.plot([1, 9    ], [ 0 + 7, 0 + 7], color='red', linewidth=lwd)
plt.plot([2, 2    ], [ 0,    -2 + 7], color='red', linewidth=lwd)
plt.plot([3, 3    ], [ 1,    -1 + 7], color='red', linewidth=lwd)
plt.plot([4, 4    ], [ 0,    -2 + 7], color='red', linewidth=lwd)
plt.plot([5, 5    ], [ 1,    -1 + 7], color='red', linewidth=lwd)
plt.plot([6, 6    ], [ 0,    -2 + 7], color='red', linewidth=lwd)
plt.plot([7, 7    ], [ 1,    -1 + 7], color='red', linewidth=lwd)
plt.plot([8, 8    ], [ 0,    -2 + 7], color='red', linewidth=lwd)
plt.plot([9, 9    ], [ 1,    -1 + 7], color='red', linewidth=lwd)
#plt.plot([3, 4    ], [ 5,     5    ], color='red', linewidth=lwd)
plt.plot([9, 10   ], [ 1,     1    ], color='red', linewidth=lwd)


# Draw the text to represent state of agent in the maze
def plot_fun(i,j):
    plt.text(i+0.5, (9-j)+0.5, 'S_{}'.format(i + j*10), size=8, ha='center')

[[plot_fun(i,j) for i in range(10)] for j in range(10)]

# Set the range of the graph
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
plt.tick_params(axis='both',
                which='both',
                bottom='off',
                top='off',
                labelbottom='off',
                right='off',
                left='off',
                labelleft='off',
                )

# Draw it!
start_x, start_y = [1 - 0.5, 10 - 0.5]
plt.text(start_x, start_y - 0.25, 'START', ha='center')
plt.text(start_y, start_x - 0.25,  'GOAL', ha='center')
line, =ax.plot([start_x], [start_y], marker="o", color='g', markersize=35)
line, =ax.plot([start_y], [start_x], marker="o", color='y', markersize=35)

# %%
# Set the Strategy parameters theta_0 (The Strategy Table)
N = np.nan
#                 up, right, down, left
theta_0_row9 = np.array([
                    [ N, 1, 1, N],# S_0
                    [ N, 1, N, 1],# S_1
                    [ N, 1, 1, 1],# S_2
                    [ N, 1, 1, 1],# S_3
                    [ N, 1, 1, 1],# S_4
                    [ N, 1, 1, 1],# S_5
                    [ N, 1, 1, 1],# S_6
                    [ N, 1, 1, 1],# S_7
                    [ N, 1, 1, 1],# S_8
                    [ N, N, 1, 1],# S_9
                   ])

theta_0_row8 = np.array([
                    [ 1, 1, 1, N],# S_10
                    [ N, N, 1, 1],# S_11
                    [ 1, 1, N, N],# S_12
                    [ 1, 1, N, 1],# S_13
                    [ 1, 1, N, 1],# S_14
                    [ 1, 1, N, 1],# S_15
                    [ 1, 1, N, 1],# S_16
                    [ 1, 1, N, 1],# S_17
                    [ 1, 1, N, 1],# S_18
                    [ 1, N, N, 1],# S_19
                   ])

theta_0_row7 = np.array([
                    [ 1, N, 1, N],# S_20
                    [ 1, 1, N, N],# S_21
                    [ N, 1, N, 1],# S_22
                    [ N, 1, N, 1],# S_23
                    [ N, 1, N, 1],# S_24
                    [ N, 1, N, 1],# S_25
                    [ N, 1, N, 1],# S_26
                    [ N, 1, N, 1],# S_27
                    [ N, 1, N, 1],# S_28
                    [ N, N, 1, 1],# S_29
                   ])

theta_0_row6 = np.array([
                    [ 1, N, 1, N],# S_30
                    [ N, 1, N, N],# S_31
                    [ N, 1, N, 1],# S_32
                    [ N, 1, 1, 1],# S_33
                    [ N, 1, N, 1],# S_34
                    [ N, 1, N, 1],# S_35
                    [ N, 1, N, 1],# S_36
                    [ N, 1, N, 1],# S_37
                    [ N, 1, N, 1],# S_38
                    [ 1, N, 1, 1],# S_39
                   ])

theta_0_row5 = np.array([
                    [ 1, N, 1, N],# S_40
                    [ N, 1, 1, N],# S_41
                    [ N, N, 1, 1],# S_42
                    [ 1, 1, 1, N],# S_43
                    [ N, N, 1, 1],# S_44
                    [ N, 1, 1, N],# S_45
                    [ N, N, 1, 1],# S_46
                    [ N, 1, 1, N],# S_47
                    [ N, N, 1, 1],# S_48
                    [ 1, N, 1, N],# S_49
                   ])

theta_0_row4 = np.array([
                    [ 1, N, 1, N],# S_50
                    [ 1, N, 1, N],# S_51
                    [ 1, N, 1, N],# S_52
                    [ 1, N, 1, N],# S_53
                    [ 1, N, 1, N],# S_54
                    [ 1, N, 1, N],# S_55
                    [ 1, N, 1, N],# S_56
                    [ 1, N, 1, N],# S_57
                    [ 1, N, 1, N],# S_58
                    [ 1, N, 1, N],# S_59
                   ])

theta_0_row3 = np.array([
                    [ 1, N, 1, N],# S_60
                    [ 1, N, 1, N],# S_61
                    [ 1, N, 1, N],# S_62
                    [ 1, N, 1, N],# S_63
                    [ 1, N, 1, N],# S_64
                    [ 1, N, 1, N],# S_65
                    [ 1, N, 1, N],# S_66
                    [ 1, N, 1, N],# S_67
                    [ 1, N, 1, N],# S_68
                    [ 1, N, 1, N],# S_69
                   ])

theta_0_row2 = np.array([
                    [ 1, N, 1, N],# S_70
                    [ 1, N, 1, N],# S_71
                    [ 1, N, 1, N],# S_72
                    [ 1, N, 1, N],# S_73
                    [ 1, N, 1, N],# S_74
                    [ 1, N, 1, N],# S_75
                    [ 1, N, 1, N],# S_76
                    [ 1, N, 1, N],# S_77
                    [ 1, N, 1, N],# S_78
                    [ 1, N, 1, N],# S_79
                   ])

theta_0_row1 = np.array([
                    [ 1, N, 1, N],# S_80
                    [ 1, N, 1, N],# S_81
                    [ 1, N, 1, N],# S_82
                    [ 1, N, 1, N],# S_83
                    [ 1, N, 1, N],# S_84
                    [ 1, N, 1, N],# S_85
                    [ 1, N, 1, N],# S_86
                    [ 1, N, 1, N],# S_87
                    [ 1, N, 1, N],# S_88
                    [ 1, N, N, N],# S_89
                   ])

theta_0_row0 = np.array([
                    [ 1, 1, N, N],# S_90
                    [ 1, N, N, 1],# S_91
                    [ 1, 1, N, N],# S_92
                    [ 1, N, N, 1],# S_93
                    [ 1, 1, N, N],# S_94
                    [ 1, N, N, 1],# S_95
                    [ 1, 1, N, N],# S_96
                    [ 1, N, N, 1],# S_97
                    [ 1, 1, N, N],# S_98
                    [ 1, N, N, 1],# S_99
                   ])

theta_0 = np.concatenate([
                    theta_0_row9,
                    theta_0_row8,
                    theta_0_row7,
                    theta_0_row6,
                    theta_0_row5,
                    theta_0_row4,
                    theta_0_row3,
                    theta_0_row2,
                    theta_0_row1,
                    theta_0_row0,
                   ])

#theta_0

# %%
def simple_convert_into_pi_from_theta(theta):
    [m, n] = theta.shape
    pi = np.zeros((m, n))

    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])

    pi = np.nan_to_num(pi)

    return pi

pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# Initialization of the Q-table
[a, b] = theta_0.shape

Q = np.random.rand(a, b) * theta_0 * 0.1

# %%
# ε-greedy , method implementatoin.

# Get action
def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    if np.random.rand() < epsilon:
        # Choose the direction according to the probability of pi[s,:]
        next_direction = np.random.choice(direction, p = pi_0[s, :])
    else:
        next_direction = direction[np.nanargmax(Q[s, :])]

    if   next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]

    if   next_direction == "up":
        s_next = s - 10
    elif next_direction == "right":
        s_next = s + 1
    elif next_direction == "down":
        s_next = s + 10
    elif next_direction == "left":
        s_next = s - 1

    return s_next

# %%
# Q-Learning, renewing the quality function Q 

def Q_learning(s, a, r, s_next, Q, eta, gamma):

    if s_next == 99:  # When reaching the end point
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])

    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next, :]) - Q[s, a])

    return Q

# %%
# Q-Learningで迷路を解く関数の定義、状態と行動の履歴および更新したQを出力


def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # スタート地点
    a = a_next = get_action(s, Q, epsilon, pi)  # 初期の行動
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト

    while (1):  # ゴールするまでループ
        a = a_next  # 行動更新

        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 次の状態を格納

        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく

        # 報酬を与え,　次の行動を求めます
        if s_next == 99:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 次の行動a_nextを求めます。

        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)

        # 終了判定
        if s_next == 99:  # ゴール地点なら終了
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# Q-Learningで迷路を解く

eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
v_diff = .0
v_diff_history = []
is_continue = True
episode = 1
current_actions_total_steps = .0
current_actions_total_steps_history = []

V = []  # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める

while is_continue:  # is_continueがFalseになるまで繰り返す
    #print("エピソード:" + str(episode))

    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2

    # Q-Learningで迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
    #print(np.sum(np.abs(new_v - v)))  # 状態価値の変化を出力

    v_diff = np.sum(np.abs(new_v - v))
    v_diff_history.append(v_diff)
    current_actions_total_steps = len(s_a_history) - 1
    current_actions_total_steps_history.append(np.abs(current_actions_total_steps))
    print( str(episode) + " : ", v_diff ,"\t  The total steps used to finish the maze is ", current_actions_total_steps )
    v = new_v
    V.append(v)  # このエピソード終了時の状態価値関数を追加

    # 500エピソード繰り返す
    episode = episode + 1
    if episode > 500:
        break
# Out:
# 1 :  4.137167818717786 	  The total steps used to finish the maze is  13440
# 2 :  0.2589867528960031 	  The total steps used to finish the maze is  1084
# 3 :  0.16299483270424547 	  The total steps used to finish the maze is  434
# 4 :  0.19117909426409185 	  The total steps used to finish the maze is  662
# 5 :  0.13955873085718454 	  The total steps used to finish the maze is  348
# 6 :  0.15956084120141528 	  The total steps used to finish the maze is  530
# 7 :  0.13023373401044214 	  The total steps used to finish the maze is  316
# 8 :  0.13114274443180432 	  The total steps used to finish the maze is  340
# 9 :  0.14029703070812113 	  The total steps used to finish the maze is  464
# 10 :  0.1201304587675659 	  The total steps used to finish the maze is  238
# 11 :  0.12989380752482804 	  The total steps used to finish the maze is  378
# 12 :  0.12917700731420587 	  The total steps used to finish the maze is  396
# 13 :  0.12257208917791393 	  The total steps used to finish the maze is  362
# 14 :  0.11274387103028624 	  The total steps used to finish the maze is  272
# 15 :  0.12089235757927494 	  The total steps used to finish the maze is  380
# 16 :  0.12369641891990796 	  The total steps used to finish the maze is  344
# 17 :  0.10532819013564268 	  The total steps used to finish the maze is  250
# 18 :  0.11316605632046625 	  The total steps used to finish the maze is  334
# 19 :  0.1079298859055292 	  The total steps used to finish the maze is  290
# 20 :  0.11005344980997547 	  The total steps used to finish the maze is  334
# 21 :  0.09666804582883802 	  The total steps used to finish the maze is  192
# 22 :  0.10335198655980607 	  The total steps used to finish the maze is  284
# 23 :  0.1073731728512368 	  The total steps used to finish the maze is  318
# 24 :  0.10304627472520689 	  The total steps used to finish the maze is  306
# 25 :  0.1643031480064 	  The total steps used to finish the maze is  678
# 26 :  0.10651785545647365 	  The total steps used to finish the maze is  376
# 27 :  0.10360458645115712 	  The total steps used to finish the maze is  378
# 28 :  0.0992773397408131 	  The total steps used to finish the maze is  336
# 29 :  0.09355319246240305 	  The total steps used to finish the maze is  276
# 30 :  0.09931959446317778 	  The total steps used to finish the maze is  376
# 31 :  0.09466964017713955 	  The total steps used to finish the maze is  324
# 32 :  0.09406244572871919 	  The total steps used to finish the maze is  364
# 33 :  0.09046971471842032 	  The total steps used to finish the maze is  280
# 34 :  0.09248678902456327 	  The total steps used to finish the maze is  364
# 35 :  0.09974944143438141 	  The total steps used to finish the maze is  470
# 36 :  0.08944568017883972 	  The total steps used to finish the maze is  342
# 37 :  0.09163482303142752 	  The total steps used to finish the maze is  422
# 38 :  0.10026726608845854 	  The total steps used to finish the maze is  510
# 39 :  0.0804439460386403 	  The total steps used to finish the maze is  288
# 40 :  0.08956510826157728 	  The total steps used to finish the maze is  408
# 41 :  0.08987097389659357 	  The total steps used to finish the maze is  476
# 42 :  0.09218092064002698 	  The total steps used to finish the maze is  526
# 43 :  0.0822632034543916 	  The total steps used to finish the maze is  386
# 44 :  0.07872450401328132 	  The total steps used to finish the maze is  318
# 45 :  0.08114080446853468 	  The total steps used to finish the maze is  394
# 46 :  0.08540648019032776 	  The total steps used to finish the maze is  502
# 47 :  0.0795419776728652 	  The total steps used to finish the maze is  432
# 48 :  0.07428248217018865 	  The total steps used to finish the maze is  308
# 49 :  0.07717223174879384 	  The total steps used to finish the maze is  418
# 50 :  0.0822851236216553 	  The total steps used to finish the maze is  532
# 51 :  0.0663899729693413 	  The total steps used to finish the maze is  220
# 52 :  0.07205869277876703 	  The total steps used to finish the maze is  378
# 53 :  0.08016592349673396 	  The total steps used to finish the maze is  556
# 54 :  0.06271408203298892 	  The total steps used to finish the maze is  196
# 55 :  0.07172305608195956 	  The total steps used to finish the maze is  418
# 56 :  0.06871530004584742 	  The total steps used to finish the maze is  362
# 57 :  0.07226703006907259 	  The total steps used to finish the maze is  480
# 58 :  0.06345461494302423 	  The total steps used to finish the maze is  266
# 59 :  0.06593772368950647 	  The total steps used to finish the maze is  378
# 60 :  0.06282161474285924 	  The total steps used to finish the maze is  292
# 61 :  0.06050275083017902 	  The total steps used to finish the maze is  276
# 62 :  0.06665480648947797 	  The total steps used to finish the maze is  470
# 63 :  0.05914466534970702 	  The total steps used to finish the maze is  228
# 64 :  0.06035214090767839 	  The total steps used to finish the maze is  338
# 65 :  0.05832964769178048 	  The total steps used to finish the maze is  270
# 66 :  0.07884752962168928 	  The total steps used to finish the maze is  864
# 67 :  0.05509089628596711 	  The total steps used to finish the maze is  220
# 68 :  0.06050618061808499 	  The total steps used to finish the maze is  444
# 69 :  0.059461689477432536 	  The total steps used to finish the maze is  398
# 70 :  0.053962972416610626 	  The total steps used to finish the maze is  264
# 71 :  0.06116156111136981 	  The total steps used to finish the maze is  516
# 72 :  0.05180949193375745 	  The total steps used to finish the maze is  230
# 73 :  0.05548845989530259 	  The total steps used to finish the maze is  388
# 74 :  0.05342066033412078 	  The total steps used to finish the maze is  324
# 75 :  0.052392221285099544 	  The total steps used to finish the maze is  306
# 76 :  0.05351613565951364 	  The total steps used to finish the maze is  376
# 77 :  0.049201227778687906 	  The total steps used to finish the maze is  238
# 78 :  0.05123405441281921 	  The total steps used to finish the maze is  352
# 79 :  0.048705312866453444 	  The total steps used to finish the maze is  242
# 80 :  0.04761136683152876 	  The total steps used to finish the maze is  248
# 81 :  0.04901439540518373 	  The total steps used to finish the maze is  296
# 82 :  0.04606394136346803 	  The total steps used to finish the maze is  226
# 83 :  0.047443918529074404 	  The total steps used to finish the maze is  298
# 84 :  0.04692389291048001 	  The total steps used to finish the maze is  286
# 85 :  0.04557514437474414 	  The total steps used to finish the maze is  262
# 86 :  0.04611503226640403 	  The total steps used to finish the maze is  310
# 87 :  0.04300742652553888 	  The total steps used to finish the maze is  180
# 88 :  0.04364133889695138 	  The total steps used to finish the maze is  250
# 89 :  0.045166579816508644 	  The total steps used to finish the maze is  328
# 90 :  0.042160595775530295 	  The total steps used to finish the maze is  194
# 91 :  0.04216362288239354 	  The total steps used to finish the maze is  248
# 92 :  0.04169264847117547 	  The total steps used to finish the maze is  218
# 93 :  0.04128579716178634 	  The total steps used to finish the maze is  246
# 94 :  0.040972855911686694 	  The total steps used to finish the maze is  232
# 95 :  0.040909534285114735 	  The total steps used to finish the maze is  256
# 96 :  0.0399463548649243 	  The total steps used to finish the maze is  226
# 97 :  0.03923885356265828 	  The total steps used to finish the maze is  202
# 98 :  0.03910231322748184 	  The total steps used to finish the maze is  244
# 99 :  0.038537185854874936 	  The total steps used to finish the maze is  212
# 100 :  0.03882951231192625 	  The total steps used to finish the maze is  258
# 101 :  0.037964734414191834 	  The total steps used to finish the maze is  228
# 102 :  0.036261954808126454 	  The total steps used to finish the maze is  166
# 103 :  0.03795279215865453 	  The total steps used to finish the maze is  278
# 104 :  0.035687170848691156 	  The total steps used to finish the maze is  170
# 105 :  0.03612602666408385 	  The total steps used to finish the maze is  216
# 106 :  0.03497848219757899 	  The total steps used to finish the maze is  166
# 107 :  0.03568090949343846 	  The total steps used to finish the maze is  254
# 108 :  0.035568356303457505 	  The total steps used to finish the maze is  228
# 109 :  0.03390694572431264 	  The total steps used to finish the maze is  170
# 110 :  0.034186013047377235 	  The total steps used to finish the maze is  208
# 111 :  0.03393635245071295 	  The total steps used to finish the maze is  228
# 112 :  0.03399216379961471 	  The total steps used to finish the maze is  254
# 113 :  0.03198267891655729 	  The total steps used to finish the maze is  122
# 114 :  0.0329261845732487 	  The total steps used to finish the maze is  232
# 115 :  0.032596139893692935 	  The total steps used to finish the maze is  206
# 116 :  0.0316052202995549 	  The total steps used to finish the maze is  190
# 117 :  0.03208809998163921 	  The total steps used to finish the maze is  218
# 118 :  0.030778481047298432 	  The total steps used to finish the maze is  160
# 119 :  0.03130570555473576 	  The total steps used to finish the maze is  220
# 120 :  0.02992268519319908 	  The total steps used to finish the maze is  148
# 121 :  0.0305088865001351 	  The total steps used to finish the maze is  228
# 122 :  0.03011708635767621 	  The total steps used to finish the maze is  202
# 123 :  0.029343011677899218 	  The total steps used to finish the maze is  166
# 124 :  0.028943017448721707 	  The total steps used to finish the maze is  172
# 125 :  0.029046034886511925 	  The total steps used to finish the maze is  178
# 126 :  0.028331298300784933 	  The total steps used to finish the maze is  174
# 127 :  0.028543629593161528 	  The total steps used to finish the maze is  186
# 128 :  0.02783790105604199 	  The total steps used to finish the maze is  166
# 129 :  0.027740356063844993 	  The total steps used to finish the maze is  184
# 130 :  0.026926772145433143 	  The total steps used to finish the maze is  146
# 131 :  0.02759592857880507 	  The total steps used to finish the maze is  236
# 132 :  0.026524393985881106 	  The total steps used to finish the maze is  128
# 133 :  0.02680217692426335 	  The total steps used to finish the maze is  212
# 134 :  0.025997278593272628 	  The total steps used to finish the maze is  138
# 135 :  0.025599803486570708 	  The total steps used to finish the maze is  148
# 136 :  0.02629960048527618 	  The total steps used to finish the maze is  228
# 137 :  0.024731626901539232 	  The total steps used to finish the maze is  98
# 138 :  0.025102643100050337 	  The total steps used to finish the maze is  172
# 139 :  0.02553041654789348 	  The total steps used to finish the maze is  228
# 140 :  0.023891695767378488 	  The total steps used to finish the maze is  98
# 141 :  0.024644243348131117 	  The total steps used to finish the maze is  192
# 142 :  0.024387295552225588 	  The total steps used to finish the maze is  198
# 143 :  0.023796164485907365 	  The total steps used to finish the maze is  170
# 144 :  0.023249879630347164 	  The total steps used to finish the maze is  116
# 145 :  0.02358792060495899 	  The total steps used to finish the maze is  204
# 146 :  0.023363906078304367 	  The total steps used to finish the maze is  182
# 147 :  0.02251341589970742 	  The total steps used to finish the maze is  112
# 148 :  0.022593998235274804 	  The total steps used to finish the maze is  186
# 149 :  0.02272027431878133 	  The total steps used to finish the maze is  180
# 150 :  0.021738571302529507 	  The total steps used to finish the maze is  106
# 151 :  0.022134650617433978 	  The total steps used to finish the maze is  178
# 152 :  0.021571301960091584 	  The total steps used to finish the maze is  148
# 153 :  0.021027244524938277 	  The total steps used to finish the maze is  134
# 154 :  0.021503361086815755 	  The total steps used to finish the maze is  176
# 155 :  0.021135583702844414 	  The total steps used to finish the maze is  160
# 156 :  0.020737945013986764 	  The total steps used to finish the maze is  154
# 157 :  0.02073618374653252 	  The total steps used to finish the maze is  162
# 158 :  0.02009530285283243 	  The total steps used to finish the maze is  136
# 159 :  0.020563030268838108 	  The total steps used to finish the maze is  188
# 160 :  0.01953152448149121 	  The total steps used to finish the maze is  98
# 161 :  0.01992518547977847 	  The total steps used to finish the maze is  188
# 162 :  0.019703071918852948 	  The total steps used to finish the maze is  166
# 163 :  0.018696494720632596 	  The total steps used to finish the maze is  80
# 164 :  0.019194146976292226 	  The total steps used to finish the maze is  158
# 165 :  0.01925525216506252 	  The total steps used to finish the maze is  172
# 166 :  0.01851429872384458 	  The total steps used to finish the maze is  134
# 167 :  0.018718892541823483 	  The total steps used to finish the maze is  162
# 168 :  0.018303939354461396 	  The total steps used to finish the maze is  142
# 169 :  0.018087770404137497 	  The total steps used to finish the maze is  148
# 170 :  0.01776232055490912 	  The total steps used to finish the maze is  104
# 171 :  0.01750844265560093 	  The total steps used to finish the maze is  114
# 172 :  0.017543346937692487 	  The total steps used to finish the maze is  148
# 173 :  0.01773077973265956 	  The total steps used to finish the maze is  166
# 174 :  0.01727869630162999 	  The total steps used to finish the maze is  152
# 175 :  0.01721770678518733 	  The total steps used to finish the maze is  152
# 176 :  0.016680467904586275 	  The total steps used to finish the maze is  128
# 177 :  0.01663275287629394 	  The total steps used to finish the maze is  112
# 178 :  0.016441446203493557 	  The total steps used to finish the maze is  136
# 179 :  0.016173625223245256 	  The total steps used to finish the maze is  128
# 180 :  0.0165892804183735 	  The total steps used to finish the maze is  176
# 181 :  0.01601057312716343 	  The total steps used to finish the maze is  146
# 182 :  0.015740414594156413 	  The total steps used to finish the maze is  100
# 183 :  0.015944669073147736 	  The total steps used to finish the maze is  182
# 184 :  0.015407249684873114 	  The total steps used to finish the maze is  102
# 185 :  0.015302978203376262 	  The total steps used to finish the maze is  134
# 186 :  0.015055588764009578 	  The total steps used to finish the maze is  134
# 187 :  0.014859522391481916 	  The total steps used to finish the maze is  122
# 188 :  0.014619923029634576 	  The total steps used to finish the maze is  86
# 189 :  0.015019029831974246 	  The total steps used to finish the maze is  156
# 190 :  0.014552036100997822 	  The total steps used to finish the maze is  132
# 191 :  0.014656444255604872 	  The total steps used to finish the maze is  154
# 192 :  0.013963227400530276 	  The total steps used to finish the maze is  82
# 193 :  0.01407711712272294 	  The total steps used to finish the maze is  128
# 194 :  0.014380763459040137 	  The total steps used to finish the maze is  176
# 195 :  0.013851380639695227 	  The total steps used to finish the maze is  134
# 196 :  0.013630882921890134 	  The total steps used to finish the maze is  100
# 197 :  0.013362425197262398 	  The total steps used to finish the maze is  112
# 198 :  0.01363056095536724 	  The total steps used to finish the maze is  158
# 199 :  0.012953855774942947 	  The total steps used to finish the maze is  70
# 200 :  0.012982875162578254 	  The total steps used to finish the maze is  116
# 201 :  0.01322172271315679 	  The total steps used to finish the maze is  154
# 202 :  0.012881066262712043 	  The total steps used to finish the maze is  128
# 203 :  0.012464259122763388 	  The total steps used to finish the maze is  76
# 204 :  0.012879458947133281 	  The total steps used to finish the maze is  152
# 205 :  0.012423115676873053 	  The total steps used to finish the maze is  128
# 206 :  0.012322695359542633 	  The total steps used to finish the maze is  100
# 207 :  0.012217382052865313 	  The total steps used to finish the maze is  124
# 208 :  0.01209380610074882 	  The total steps used to finish the maze is  126
# 209 :  0.012214909704610283 	  The total steps used to finish the maze is  150
# 210 :  0.011481510782458838 	  The total steps used to finish the maze is  60
# 211 :  0.011957889085633331 	  The total steps used to finish the maze is  150
# 212 :  0.011420880451057496 	  The total steps used to finish the maze is  82
# 213 :  0.011521037797357584 	  The total steps used to finish the maze is  128
# 214 :  0.01153966179216903 	  The total steps used to finish the maze is  140
# 215 :  0.011138986162320914 	  The total steps used to finish the maze is  112
# 216 :  0.010972356700922972 	  The total steps used to finish the maze is  82
# 217 :  0.011233029129115325 	  The total steps used to finish the maze is  140
# 218 :  0.010798616315704583 	  The total steps used to finish the maze is  114
# 219 :  0.010866302517001762 	  The total steps used to finish the maze is  106
# 220 :  0.010702739687808587 	  The total steps used to finish the maze is  120
# 221 :  0.01063527720093625 	  The total steps used to finish the maze is  138
# 222 :  0.010464252619193263 	  The total steps used to finish the maze is  106
# 223 :  0.010131560563545207 	  The total steps used to finish the maze is  62
# 224 :  0.010250811719920504 	  The total steps used to finish the maze is  128
# 225 :  0.010147509259128676 	  The total steps used to finish the maze is  88
# 226 :  0.010073744985937237 	  The total steps used to finish the maze is  122
# 227 :  0.010121466617411104 	  The total steps used to finish the maze is  138
# 228 :  0.009587498453714486 	  The total steps used to finish the maze is  64
# 229 :  0.009898599873413287 	  The total steps used to finish the maze is  142
# 230 :  0.009647456119849364 	  The total steps used to finish the maze is  88
# 231 :  0.009498530327822925 	  The total steps used to finish the maze is  110
# 232 :  0.009537160488167693 	  The total steps used to finish the maze is  130
# 233 :  0.009271703886494858 	  The total steps used to finish the maze is  76
# 234 :  0.009374018671445505 	  The total steps used to finish the maze is  146
# 235 :  0.009352397094443823 	  The total steps used to finish the maze is  134
# 236 :  0.008906279048462709 	  The total steps used to finish the maze is  66
# 237 :  0.008939824089314312 	  The total steps used to finish the maze is  114
# 238 :  0.008896333240647154 	  The total steps used to finish the maze is  90
# 239 :  0.008756821805398066 	  The total steps used to finish the maze is  110
# 240 :  0.008767053813033053 	  The total steps used to finish the maze is  120
# 241 :  0.008648480068057816 	  The total steps used to finish the maze is  88
# 242 :  0.00847853172126961 	  The total steps used to finish the maze is  106
# 243 :  0.008630590233216374 	  The total steps used to finish the maze is  122
# 244 :  0.008326931245789596 	  The total steps used to finish the maze is  110
# 245 :  0.008139152581456048 	  The total steps used to finish the maze is  64
# 246 :  0.008215007081938522 	  The total steps used to finish the maze is  108
# 247 :  0.008103864171973962 	  The total steps used to finish the maze is  114
# 248 :  0.008103408894256224 	  The total steps used to finish the maze is  92
# 249 :  0.007704846154941852 	  The total steps used to finish the maze is  52
# 250 :  0.007851830384017565 	  The total steps used to finish the maze is  114
# 251 :  0.007952905866744417 	  The total steps used to finish the maze is  134
# 252 :  0.00760593249768203 	  The total steps used to finish the maze is  66
# 253 :  0.007723246254031287 	  The total steps used to finish the maze is  116
# 254 :  0.007368697199197837 	  The total steps used to finish the maze is  58
# 255 :  0.007335765527804021 	  The total steps used to finish the maze is  76
# 256 :  0.007485152773211095 	  The total steps used to finish the maze is  92
# 257 :  0.007334049728611689 	  The total steps used to finish the maze is  108
# 258 :  0.007142227290106883 	  The total steps used to finish the maze is  62
# 259 :  0.007394151878623262 	  The total steps used to finish the maze is  136
# 260 :  0.006962225613552716 	  The total steps used to finish the maze is  66
# 261 :  0.007017725629628554 	  The total steps used to finish the maze is  102
# 262 :  0.007027558755208899 	  The total steps used to finish the maze is  86
# 263 :  0.006927144111010693 	  The total steps used to finish the maze is  112
# 264 :  0.006843567326867 	  The total steps used to finish the maze is  80
# 265 :  0.006734814484527399 	  The total steps used to finish the maze is  100
# 266 :  0.006525301933822872 	  The total steps used to finish the maze is  58
# 267 :  0.0068639664163209725 	  The total steps used to finish the maze is  138
# 268 :  0.006583098843989529 	  The total steps used to finish the maze is  106
# 269 :  0.006304014378373629 	  The total steps used to finish the maze is  50
# 270 :  0.006539092081287267 	  The total steps used to finish the maze is  92
# 271 :  0.0064030809400230215 	  The total steps used to finish the maze is  112
# 272 :  0.006303790423327358 	  The total steps used to finish the maze is  102
# 273 :  0.006075544247080354 	  The total steps used to finish the maze is  54
# 274 :  0.006257216412620174 	  The total steps used to finish the maze is  80
# 275 :  0.006176108542759111 	  The total steps used to finish the maze is  116
# 276 :  0.006052112887343512 	  The total steps used to finish the maze is  100
# 277 :  0.006108253959683297 	  The total steps used to finish the maze is  84
# 278 :  0.005966897833157464 	  The total steps used to finish the maze is  108
# 279 :  0.00597598278295549 	  The total steps used to finish the maze is  80
# 280 :  0.005693098935301618 	  The total steps used to finish the maze is  56
# 281 :  0.005847143449717963 	  The total steps used to finish the maze is  124
# 282 :  0.005932166793256796 	  The total steps used to finish the maze is  122
# 283 :  0.005533373384681841 	  The total steps used to finish the maze is  56
# 284 :  0.005651397071842179 	  The total steps used to finish the maze is  114
# 285 :  0.005680347267775655 	  The total steps used to finish the maze is  82
# 286 :  0.0053696027716835125 	  The total steps used to finish the maze is  54
# 287 :  0.005479813664971911 	  The total steps used to finish the maze is  106
# 288 :  0.005508732958346438 	  The total steps used to finish the maze is  80
# 289 :  0.005347514282919774 	  The total steps used to finish the maze is  92
# 290 :  0.005189297553319741 	  The total steps used to finish the maze is  62
# 291 :  0.0053468024401230295 	  The total steps used to finish the maze is  76
# 292 :  0.005226076693806697 	  The total steps used to finish the maze is  104
# 293 :  0.005177201966960427 	  The total steps used to finish the maze is  106
# 294 :  0.004973514941682557 	  The total steps used to finish the maze is  56
# 295 :  0.005182680739589915 	  The total steps used to finish the maze is  76
# 296 :  0.005051328583389237 	  The total steps used to finish the maze is  112
# 297 :  0.004826064058081202 	  The total steps used to finish the maze is  52
# 298 :  0.005171939061627132 	  The total steps used to finish the maze is  116
# 299 :  0.004735300592282016 	  The total steps used to finish the maze is  52
# 300 :  0.004960162816489751 	  The total steps used to finish the maze is  76
# 301 :  0.004822651220198236 	  The total steps used to finish the maze is  110
# 302 :  0.004613052464338885 	  The total steps used to finish the maze is  52
# 303 :  0.005042446311065413 	  The total steps used to finish the maze is  136
# 304 :  0.004528616330865218 	  The total steps used to finish the maze is  52
# 305 :  0.004641577094818517 	  The total steps used to finish the maze is  110
# 306 :  0.004717411479808789 	  The total steps used to finish the maze is  72
# 307 :  0.004407499009303934 	  The total steps used to finish the maze is  50
# 308 :  0.004357763410003039 	  The total steps used to finish the maze is  52
# 309 :  0.004757198859340613 	  The total steps used to finish the maze is  128
# 310 :  0.004288528995755674 	  The total steps used to finish the maze is  52
# 311 :  0.0043960851445366475 	  The total steps used to finish the maze is  108
# 312 :  0.004198096444655934 	  The total steps used to finish the maze is  50
# 313 :  0.004516312826192517 	  The total steps used to finish the maze is  80
# 314 :  0.0043025129373445384 	  The total steps used to finish the maze is  112
# 315 :  0.004084851979115647 	  The total steps used to finish the maze is  50
# 316 :  0.00447458360405107 	  The total steps used to finish the maze is  116
# 317 :  0.004024658906831126 	  The total steps used to finish the maze is  52
# 318 :  0.004148854540533108 	  The total steps used to finish the maze is  114
# 319 :  0.003943960706318601 	  The total steps used to finish the maze is  52
# 320 :  0.0042867973871086465 	  The total steps used to finish the maze is  76
# 321 :  0.004008380165967858 	  The total steps used to finish the maze is  100
# 322 :  0.0038702776546493327 	  The total steps used to finish the maze is  66
# 323 :  0.004268201851739202 	  The total steps used to finish the maze is  114
# 324 :  0.003781194615641123 	  The total steps used to finish the maze is  52
# 325 :  0.003737310151678677 	  The total steps used to finish the maze is  50
# 326 :  0.003863752597221019 	  The total steps used to finish the maze is  112
# 327 :  0.004063630718840479 	  The total steps used to finish the maze is  74
# 328 :  0.0036446363471764895 	  The total steps used to finish the maze is  52
# 329 :  0.004151905277706815 	  The total steps used to finish the maze is  136
# 330 :  0.003587328018990688 	  The total steps used to finish the maze is  50
# 331 :  0.0035476231113262292 	  The total steps used to finish the maze is  50
# 332 :  0.003643911624405574 	  The total steps used to finish the maze is  102
# 333 :  0.00393139813774886 	  The total steps used to finish the maze is  86
# 334 :  0.0034599339912215867 	  The total steps used to finish the maze is  50
# 335 :  0.0035465669690689615 	  The total steps used to finish the maze is  98
# 336 :  0.0033953970898508495 	  The total steps used to finish the maze is  52
# 337 :  0.0033545188628979713 	  The total steps used to finish the maze is  50
# 338 :  0.0039001739890944026 	  The total steps used to finish the maze is  118
# 339 :  0.003309341182844417 	  The total steps used to finish the maze is  52
# 340 :  0.0032779322478719156 	  The total steps used to finish the maze is  54
# 341 :  0.003354285963386093 	  The total steps used to finish the maze is  98
# 342 :  0.0037541512193307205 	  The total steps used to finish the maze is  86
# 343 :  0.0032007157335478993 	  The total steps used to finish the maze is  54
# 344 :  0.00327797912259438 	  The total steps used to finish the maze is  100
# 345 :  0.0031310297425045236 	  The total steps used to finish the maze is  52
# 346 :  0.0035757173546436694 	  The total steps used to finish the maze is  62
# 347 :  0.0030838162692643145 	  The total steps used to finish the maze is  52
# 348 :  0.003168983480504735 	  The total steps used to finish the maze is  98
# 349 :  0.003600659987143305 	  The total steps used to finish the maze is  82
# 350 :  0.0030095533254614736 	  The total steps used to finish the maze is  50
# 351 :  0.003050537886898787 	  The total steps used to finish the maze is  84
# 352 :  0.0029573002530317444 	  The total steps used to finish the maze is  54
# 353 :  0.0029185869300216638 	  The total steps used to finish the maze is  50
# 354 :  0.003419416109083959 	  The total steps used to finish the maze is  60
# 355 :  0.002996239873682885 	  The total steps used to finish the maze is  100
# 356 :  0.002858970879153921 	  The total steps used to finish the maze is  54
# 357 :  0.0028199493606421468 	  The total steps used to finish the maze is  50
# 358 :  0.0028852157828440266 	  The total steps used to finish the maze is  88
# 359 :  0.003434867751690101 	  The total steps used to finish the maze is  78
# 360 :  0.0027552720421231977 	  The total steps used to finish the maze is  50
# 361 :  0.0027275114184361596 	  The total steps used to finish the maze is  50
# 362 :  0.0026978007923918507 	  The total steps used to finish the maze is  50
# 363 :  0.002793042990736995 	  The total steps used to finish the maze is  102
# 364 :  0.0026453915243328796 	  The total steps used to finish the maze is  50
# 365 :  0.003307111313450956 	  The total steps used to finish the maze is  72
# 366 :  0.0026102314148325357 	  The total steps used to finish the maze is  50
# 367 :  0.0026980385024257874 	  The total steps used to finish the maze is  102
# 368 :  0.002563085234073689 	  The total steps used to finish the maze is  54
# 369 :  0.0025325576486624965 	  The total steps used to finish the maze is  50
# 370 :  0.0025070484766433624 	  The total steps used to finish the maze is  50
# 371 :  0.0024809667462171274 	  The total steps used to finish the maze is  50
# 372 :  0.0033654068004516347 	  The total steps used to finish the maze is  120
# 373 :  0.0024501738287356165 	  The total steps used to finish the maze is  50
# 374 :  0.0024253917728182667 	  The total steps used to finish the maze is  50
# 375 :  0.0024008175914269946 	  The total steps used to finish the maze is  50
# 376 :  0.0023765134005638115 	  The total steps used to finish the maze is  50
# 377 :  0.0023518946594821323 	  The total steps used to finish the maze is  50
# 378 :  0.00326425478439169 	  The total steps used to finish the maze is  114
# 379 :  0.0023235581205343176 	  The total steps used to finish the maze is  50
# 380 :  0.002299957948487909 	  The total steps used to finish the maze is  50
# 381 :  0.002277924417025807 	  The total steps used to finish the maze is  52
# 382 :  0.0022539793410382035 	  The total steps used to finish the maze is  50
# 383 :  0.002231218585040322 	  The total steps used to finish the maze is  50
# 384 :  0.0022086531409208675 	  The total steps used to finish the maze is  50
# 385 :  0.0021858987183177945 	  The total steps used to finish the maze is  50
# 386 :  0.0022723766929831904 	  The total steps used to finish the maze is  98
# 387 :  0.002142715022270053 	  The total steps used to finish the maze is  50
# 388 :  0.002121194652448753 	  The total steps used to finish the maze is  50
# 389 :  0.0020998692014461 	  The total steps used to finish the maze is  50
# 390 :  0.002078735916781814 	  The total steps used to finish the maze is  50
# 391 :  0.0020577920434404423 	  The total steps used to finish the maze is  50
# 392 :  0.002037034825454746 	  The total steps used to finish the maze is  50
# 393 :  0.002016652217621702 	  The total steps used to finish the maze is  50
# 394 :  0.0019964771134894045 	  The total steps used to finish the maze is  50
# 395 :  0.0019764939923854114 	  The total steps used to finish the maze is  50
# 396 :  0.001956700323133373 	  The total steps used to finish the maze is  50
# 397 :  0.0019370935902942015 	  The total steps used to finish the maze is  50
# 398 :  0.0019176712936157456 	  The total steps used to finish the maze is  50
# 399 :  0.0018984309475865101 	  The total steps used to finish the maze is  50
# 400 :  0.0018793700810862874 	  The total steps used to finish the maze is  50
# 401 :  0.0018604862371303043 	  The total steps used to finish the maze is  50
# 402 :  0.0018417769727057452 	  The total steps used to finish the maze is  50
# 403 :  0.001823239858688672 	  The total steps used to finish the maze is  50
# 404 :  0.0018048724798459207 	  The total steps used to finish the maze is  50
# 405 :  0.0017866724349132521 	  The total steps used to finish the maze is  50
# 406 :  0.0017686373367468656 	  The total steps used to finish the maze is  50
# 407 :  0.0017507648125460202 	  The total steps used to finish the maze is  50
# 408 :  0.0017330525041435495 	  The total steps used to finish the maze is  50
# 409 :  0.0017154980683578352 	  The total steps used to finish the maze is  50
# 410 :  0.0016980991774083916 	  The total steps used to finish the maze is  50
# 411 :  0.0016808535193875594 	  The total steps used to finish the maze is  50
# 412 :  0.001663758798785529 	  The total steps used to finish the maze is  50
# 413 :  0.0016468127370705952 	  The total steps used to finish the maze is  50
# 414 :  0.001630013073312561 	  The total steps used to finish the maze is  50
# 415 :  0.0016133575648557418 	  The total steps used to finish the maze is  50
# 416 :  0.0015968439880324258 	  The total steps used to finish the maze is  50
# 417 :  0.0015804701389156965 	  The total steps used to finish the maze is  50
# 418 :  0.001564233834108498 	  The total steps used to finish the maze is  50
# 419 :  0.001548132911565781 	  The total steps used to finish the maze is  50
# 420 :  0.0015321652314460683 	  The total steps used to finish the maze is  50
# 421 :  0.0015163286769913843 	  The total steps used to finish the maze is  50
# 422 :  0.0015006211554283336 	  The total steps used to finish the maze is  50
# 423 :  0.0014850405988918317 	  The total steps used to finish the maze is  50
# 424 :  0.0014695849653645501 	  The total steps used to finish the maze is  50
# 425 :  0.0014542522396309994 	  The total steps used to finish the maze is  50
# 426 :  0.001439040434242729 	  The total steps used to finish the maze is  50
# 427 :  0.0014239475904899547 	  The total steps used to finish the maze is  50
# 428 :  0.001408971779378303 	  The total steps used to finish the maze is  50
# 429 :  0.0013941111026055256 	  The total steps used to finish the maze is  50
# 430 :  0.001379363693537246 	  The total steps used to finish the maze is  50
# 431 :  0.001364727718175631 	  The total steps used to finish the maze is  50
# 432 :  0.0013502013761199684 	  The total steps used to finish the maze is  50
# 433 :  0.0013357829015160775 	  The total steps used to finish the maze is  50
# 434 :  0.0013214705639876744 	  The total steps used to finish the maze is  50
# 435 :  0.001307262669552809 	  The total steps used to finish the maze is  50
# 436 :  0.0012931575615166924 	  The total steps used to finish the maze is  50
# 437 :  0.001279153621340346 	  The total steps used to finish the maze is  50
# 438 :  0.0012652492694820434 	  The total steps used to finish the maze is  50
# 439 :  0.0012514429662080864 	  The total steps used to finish the maze is  50
# 440 :  0.0012377332123709585 	  The total steps used to finish the maze is  50
# 441 :  0.0012241185501505082 	  The total steps used to finish the maze is  50
# 442 :  0.0012105975637576583 	  The total steps used to finish the maze is  50
# 443 :  0.0011971688800954984 	  The total steps used to finish the maze is  50
# 444 :  0.0011838311693786498 	  The total steps used to finish the maze is  50
# 445 :  0.0011705831457057554 	  The total steps used to finish the maze is  50
# 446 :  0.0011574235675829963 	  The total steps used to finish the maze is  50
# 447 :  0.0011443512383995929 	  The total steps used to finish the maze is  50
# 448 :  0.0011313650068495152 	  The total steps used to finish the maze is  50
# 449 :  0.0011184637673003445 	  The total steps used to finish the maze is  50
# 450 :  0.0011056464601061687 	  The total steps used to finish the maze is  50
# 451 :  0.001092912071863842 	  The total steps used to finish the maze is  50
# 452 :  0.001080259635611352 	  The total steps used to finish the maze is  50
# 453 :  0.0010676882309653716 	  The total steps used to finish the maze is  50
# 454 :  0.0010551969842015685 	  The total steps used to finish the maze is  50
# 455 :  0.0010427850682692356 	  The total steps used to finish the maze is  50
# 456 :  0.001030451702748046 	  The total steps used to finish the maze is  50
# 457 :  0.0010181961537403573 	  The total steps used to finish the maze is  50
# 458 :  0.0010060177337015092 	  The total steps used to finish the maze is  50
# 459 :  0.0009939158012071251 	  The total steps used to finish the maze is  50
# 460 :  0.0009818897606571294 	  The total steps used to finish the maze is  50
# 461 :  0.0009699390619180388 	  The total steps used to finish the maze is  50
# 462 :  0.0009580631999022387 	  The total steps used to finish the maze is  50
# 463 :  0.0009462617140855762 	  The total steps used to finish the maze is  50
# 464 :  0.0009345341879640123 	  The total steps used to finish the maze is  50
# 465 :  0.0009228802484494713 	  The total steps used to finish the maze is  50
# 466 :  0.0009112995652075721 	  The total steps used to finish the maze is  50
# 467 :  0.0008997918499346722 	  The total steps used to finish the maze is  50
# 468 :  0.000888356855581739 	  The total steps used to finish the maze is  50
# 469 :  0.0008769943755186631 	  The total steps used to finish the maze is  50
# 470 :  0.0008657042426477733 	  The total steps used to finish the maze is  50
# 471 :  0.0008544863284634763 	  The total steps used to finish the maze is  50
# 472 :  0.0008433405420615408 	  The total steps used to finish the maze is  50
# 473 :  0.0008322668291009968 	  The total steps used to finish the maze is  50
# 474 :  0.0008212651707180903 	  The total steps used to finish the maze is  50
# 475 :  0.0008103355823965111 	  The total steps used to finish the maze is  50
# 476 :  0.0007994781127965522 	  The total steps used to finish the maze is  50
# 477 :  0.000788692842542586 	  The total steps used to finish the maze is  50
# 478 :  0.0007779798829746323 	  The total steps used to finish the maze is  50
# 479 :  0.0007673393748650452 	  The total steps used to finish the maze is  50
# 480 :  0.0007567714871019799 	  The total steps used to finish the maze is  50
# 481 :  0.0007462764153449803 	  The total steps used to finish the maze is  50
# 482 :  0.0007358543806514667 	  The total steps used to finish the maze is  50
# 483 :  0.0007255056280805513 	  The total steps used to finish the maze is  50
# 484 :  0.0007152304252750796 	  The total steps used to finish the maze is  50
# 485 :  0.0007050290610247241 	  The total steps used to finish the maze is  50
# 486 :  0.0006949018438133421 	  The total steps used to finish the maze is  50
# 487 :  0.0006848491003535878 	  The total steps used to finish the maze is  50
# 488 :  0.000674871174110343 	  The total steps used to finish the maze is  50
# 489 :  0.0006649684238185191 	  The total steps used to finish the maze is  50
# 490 :  0.0006551412219949378 	  The total steps used to finish the maze is  50
# 491 :  0.0006453899534485069 	  The total steps used to finish the maze is  50
# 492 :  0.0006357150137916031 	  The total steps used to finish the maze is  50
# 493 :  0.0006261168079562691 	  The total steps used to finish the maze is  50
# 494 :  0.0006165957487147722 	  The total steps used to finish the maze is  50
# 495 :  0.0006071522552114042 	  The total steps used to finish the maze is  50
# 496 :  0.0005977867515046566 	  The total steps used to finish the maze is  50
# 497 :  0.0005884996651241928 	  The total steps used to finish the maze is  50
# 498 :  0.0005792914256444082 	  The total steps used to finish the maze is  50
# 499 :  0.0005701624632776883 	  The total steps used to finish the maze is  50
# 500 :  0.0005611132074884576 	  The total steps used to finish the maze is  50

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
import matplotlib
from matplotlib import animation, rc
matplotlib.rcParams['animation.embed_limit'] = 2**128

from IPython.display import HTML


def init():
    '''背景画像の初期化'''
    line.set_data([], [])
    return (line,)


def animate(i):
    '''フレームごとの描画内容'''
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 10) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 9.5 - int(state / 10)  # y座標は3で割った商を9.5から引く
    line.set_data(x, y)
    return (line,)

#　初期化関数とフレームごとの描画関数を用いて動画を作成する
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

#HTML(anim.to_jshtml())
rc('animation', html='jshtml')
anim

# %%
plt.plot(v_diff_history)

# %%
plt.plot(np.log(v_diff_history/v_diff_history[-1]))

# %%
plt.plot(current_actions_total_steps_history)

# %%
current_actions_total_steps_history[-1]
# Out:
# 50

# %%
new_list = [x/current_actions_total_steps_history[-1] for x in current_actions_total_steps_history]
new_list_log = np.log(new_list)
plt.plot(new_list_log)

# %%
# 状態価値の変化を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from matplotlib import animation, rc
matplotlib.rcParams['animation.embed_limit'] = 2**128

from IPython.display import HTML
import matplotlib.cm as cm  # color map


def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)


def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    
    # Draw the text to represent state of agent in the maze
    def plot_fun(i,xid,yid):
        state_id = xid + 10*(yid)
        if state_id == 99:
            color_map = cm.jet(1.0)
        else:
            color_map = cm.jet(V[i][state_id])
            
        line, = ax.plot([0.5+xid], [9.5-yid], marker="s",color=color_map,
                        markersize=65)

    [[plot_fun(i,xid,yid) for xid in range(10)] for yid in range(10)]

    return (line,)


#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    #fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)
    fig, animate, init_func=init, frames=10, interval=200, repeat=False)

#HTML(anim.to_jshtml())
rc('animation', html='jshtml')
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img947faf06022e49d0a6577f80e890ccff">
#   <div class="anim-controls">
#     <input id="_anim_slider947faf06022e49d0a6577f80e890ccff" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim947faf06022e49d0a6577f80e890ccff.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim947faf06022e49d0a6577f80e890ccff.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select947faf06022e49d0a6577f80e890ccff" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_947faf06022e49d0a6577f80e890ccff"
#              checked>
#       <label for="_anim_radio1_947faf06022e49d0a6577f80e890ccff">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_947faf06022e49d0a6577f80e890ccff"
#              >
#       <label for="_anim_radio2_947faf06022e49d0a6577f80e890ccff">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_947faf06022e49d0a6577f80e890ccff"
#              >
#       <label for="_anim_radio3_947faf06022e49d0a6577f80e890ccff">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img947faf06022e49d0a6577f80e890ccff";
#     var slider_id = "_anim_slider947faf06022e49d0a6577f80e890ccff";
#     var loop_select_id = "_anim_loop_select947faf06022e49d0a6577f80e890ccff";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nOzdeZgcVdmw8XvIZCdh3xcRRXYkGAVF\
# XxEEBCMIAWQVXsAoKoKIgCgiIBJZ3BDFuAAfKAjqKwiCAoqyyA4StoBKZJF9SUIWss33x9Nt93R6\
# MjndU93Vlft3XbnoqaoOz8k5deqpc07VdPX09PQgSZIkaYks0+4AJEmSpE5iAi1JkiQlMIGWJEmS\
# EphAS5IkSQlMoCVJkqQEJtCSJElSAhNoSZIkKYEJtCRJkpTABFqSJElKYAItSZIkJTCBliRJkhKY\
# QEuSJEkJTKAlSZKkBCbQkiRJUgITaEmSJCmBCbQkSZKUwARakiRJSmACLUmSJCUwgZYkSZISmEBL\
# kiRJCUygJUmSpAQm0JIkSVICE2hJkiQpgQm0JEmSlMAEWpIkSUpgAi1JkiQlMIGWJEmSEphAS5Ik\
# SQlMoCVJkqQEJtCSJElSAhNoSZ
